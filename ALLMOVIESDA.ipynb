# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("AllMovies.csv",encoding="latin-1")

# %%
import matplotlib as plt

# %%
df.dropna(subset=['Length'],axis=0,inplace=True)

# %%
df.corr()
# Out:
#              Length    Rating  Metascore     Votes     Gross
# Length     1.000000  0.417134   0.303782  0.391345  0.308839
# Rating     0.417134  1.000000   0.739690  0.462494  0.210594
# Metascore  0.303782  0.739690   1.000000  0.332230  0.176599
# Votes      0.391345  0.462494   0.332230  1.000000  0.639276
# Gross      0.308839  0.210594   0.176599  0.639276  1.000000

# %%
vs = ['Length', 'Rating', 'Metascore', 'Votes','Gross']
sns.pairplot(df[vs])
